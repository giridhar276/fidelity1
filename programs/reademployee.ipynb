# %%
import pandas as pd

# %%
df = pd.read_csv("empinfo.csv")

# %%
df

# %%
type(df)

# %%
# display first 10 records
df.head(5)

# %%
# display last  3 records
df.tail(3)

# %%
output = df.head(5)
output.to_csv("first5recoords.csv")

# %%
# display (rows,columns)
df.shape

# %%
# display datatype of ech column
df.dtypes

# %%
# diplay 3rd to 10th record only
#df.iloc[rows,columns]
df.iloc[3:11]

# %%
#df.iloc[rows, columns]
df.iloc[3:11, 1:4]

# %%
output = df.iloc[3:11, 1:4]
output.to_csv("fewrows.csv")

# %%
# display only one column
df['workclass']

# %%
# display more
df[['workclass','education','age']]

# %%
# remove duplicates from dataframe
df.drop_duplicates()  # will just diplay

# %%
df.drop_duplicates(inplace=True)  # existing df will be updated

# %%
condition = df['gender'] == ' Male'
df[condition]

#or
df[df['gender'] == ' Male']

# %%
# display all the records where workclass is Private and gender is Female
cond1 = df['workclass'] == ' Private'
cond2 = df['gender'] == ' Female'

df[cond1 & cond2 ]

# %%
## display all the records where workclass is Private and gender is Female
#df[(cond1) & (cond2)]
df[( df['workclass'] == ' Private') & ( df['gender'] == ' Female')]

# %%
# sort values - ascending order
df.sort_values('age')

# %%
# sorting in descending order
df.sort_values('age', ascending=False)

# %%
# display occurence of each item
df['workclass'].value_counts()

# %%
# display all unique workclasses
df['workclass'].unique()

# %%
# display all no. of unique workclasses
df['workclass'].nunique()

# %%
df.dropna() # drop rows with any column having null data

# %%
df.fillna(0) # replace all null values with 0
